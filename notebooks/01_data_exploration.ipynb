# %%
import pandas as pd

games = pd.read_csv('../data/raw/games.csv')
games.head()
# Out:
#            game_id  season game_type  week     gameday   weekday gametime  \
# 0   2019_01_GB_CHI    2019       REG     1  2019-09-05  Thursday    20:20
# 1   2019_01_LA_CAR    2019       REG     1  2019-09-08    Sunday    13:00
# 2  2019_01_TEN_CLE    2019       REG     1  2019-09-08    Sunday    13:00
# 3   2019_01_KC_JAX    2019       REG     1  2019-09-08    Sunday    13:00
# 4  2019_01_BAL_MIA    2019       REG     1  2019-09-08    Sunday    13:00
#
#   away_team  away_score home_team  ...  away_qb_id  home_qb_id  \
# 0        GB          10       CHI  ...  00-0023459  00-0033869
# 1        LA          30       CAR  ...  00-0033106  00-0027939
# 2       TEN          43       CLE  ...  00-0032268  00-0034855
# 3        KC          40       JAX  ...  00-0033873  00-0029567
# 4       BAL          59       MIA  ...  00-0034796  00-0023682
#
#       away_qb_name      home_qb_name     away_coach        home_coach  \
# ...

# %%
#checking to see what columns are not usefull

games['game_type'].unique()
# Out:
# <ArrowStringArray>
# ['REG', 'WC', 'DIV', 'CON', 'SB']
# Length: 5, dtype: str

# %%
games = games[games['game_type'] == 'REG']

# %%
print(games['game_type'].value_counts())
print(f"Total games remaining: {len(games)}")
# Out:
# game_type
# REG    1871
# Name: count, dtype: int64
# Total games remaining: 1871

# %%
import nflreadpy as nfl

stats = nfl.load_stats(seasons=[2024])
stats = stats.to_pandas()
print(stats.columns.tolist())
print(stats.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import nflreadpy as nfl
#       2
# ----> 3 stats = nfl.load_stats(seasons=[2024])
#       4 stats = stats.to_pandas()
#       5 print(stats.columns.tolist())
#       6 print(stats.head())
#
# TypeError: 'module' object is not callable
